# %% [markdown]
# <img src="https://www.ine.pt/img/n_logotipo.gif"/>
#
# # Modulo 3 - Python Data Exploration and Visualization Basics
# * Importar dados públicos a partir de fontes externas
# * Criar gráficos básicos utilizando MATPLOTLIB\PYPLOT e SEABORN
#     * Diferentes tipos de gráficos
#     * Técnicas de visualização

# %% [markdown]
# ## Fontes Externas

# %% [markdown]
# **Listagem de algumas fontes**
#
# * [MicroDados INE](https://www.ine.pt/xportal/xmain?xpid=INE&xpgid=ine_pufs&menuBOUI=13707095&contexto=up&selTab=tab5&xlang=pt)
# * [Dados GOV](https://dados.gov.pt/)
# * [SNS Dados](https://transparencia.sns.gov.pt/explore/dataset/monitorizacao-sazonal-csh/export/?disjunctive.ars&disjunctive.indicador)
# * [DATA EUROPA](https://data.europa.eu/en)
# * [Kaggle Datasets](https://www.kaggle.com/datasets)
# * [Google Datsets Search](https://datasetsearch.research.google.com/)
# * [Datahub Open Data](https://datahub.io/)

# %% [markdown]
# ### Importar Dados Externos para Pandas Dataframe
# * Exemplo CSV: [Despesa com Medicamentos nos Hospitais do SNS](https://dados.gov.pt/pt/datasets/despesa-com-medicamentos-nos-hospitais-do-sns-1/)
# * Exemplo XLSX: [Classificação Etária de Teatro](https://data.europa.eu/data/datasets/classificacao-etaria-de-teatro?locale=pt)

# %%
# Obter dados a partir do Link Direto ao dados
# Importar Bibliotecas
# No ambiente formação devem-se utilizar os ficheiros locais (poderá dar erro "http error 404")

import pandas as pd
import requests 
# Link direto para ficheiro CSV: Despesa com Medicamentos nos Hospitais do SNS
ficheiro = r'https://dados.gov.pt/pt/datasets/r/8803343f-6e1b-47de-87ac-26432adb45f0'

# Importar num Pandas Dataframe
df = pd.read_csv(ficheiro, sep=';')

# Informação
print(df.head(5))
print(df.info())
print(df.describe())

# %%
# Ler Dados INE - Produção Industrial Bruta
# Import Packages openxyl para poder trabalhar com XLSX
import pandas as pd
import openpyxl
import numpy as np

# Link Direto para ficheiro XLSX
ficheiro = r'https://dados.gov.pt/s/resources/classificacao-etaria-de-teatro/20240331-230417/classificacaoetariateatro.xlsx'
# Importar num DataFrame
df = pd.read_excel(ficheiro) 
# Argumentos uteis: skiprows=[0,1], usecols='A', nrows=2, header=None, sheet_name='Sheet1'

# Mostrar primeiras 3 linhas e ultimas 3 linhas (head e tail em conjunto)
# Utilizar iloc e numpy
print (df.iloc[np.r_[0:3, -3:0]])  # head e tail
print(df.info())
print(df.describe())
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[1], line 10
#       8 ficheiro = r'https://dados.gov.pt/s/resources/classificacao-etaria-de-teatro/20240331-230417/classificacaoetariateatro.xlsx'
#       9 # Importar num DataFrame
# ---> 10 df = pd.read_excel(ficheiro)
#      11 # Argumentos uteis: skiprows=[0,1], usecols='A', nrows=2, header=None, sheet_name='Sheet1'
#      12
#      13 # Mostrar primeiras 3 linhas e ultimas 3 linhas (head e tail em conjunto)
#      14 # Utilizar iloc e numpy
#      15 print (df.iloc[np.r_[0:3, -3:0]])  # head e tail
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1563, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1561     ext = "xls"
#    1562 else:
# -> 1563     ext = inspect_excel_format(
#    1564         content_or_path=path_or_buffer, storage_options=storage_options
#    1565     )
#    1566     if ext is None:
#    1567         raise ValueError(
#    1568             "Excel file format cannot be determined, you must specify "
#    1569             "an engine manually."
#    1570         )
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:1419, in inspect_excel_format(content_or_path, storage_options)
#    1416 if isinstance(content_or_path, bytes):
#    1417     content_or_path = BytesIO(content_or_path)
# -> 1419 with get_handle(
#    1420     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1421 ) as handle:
#    1422     stream = handle.handle
#    1423     stream.seek(0)
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:718, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     715     codecs.lookup_error(errors)
#     717 # open URLs
# --> 718 ioargs = _get_filepath_or_buffer(
#     719     path_or_buf,
#     720     encoding=encoding,
#     721     compression=compression,
#     722     mode=mode,
#     723     storage_options=storage_options,
#     724 )
#     726 handle = ioargs.filepath_or_buffer
#     727 handles: list[BaseBuffer]
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:372, in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     370 # assuming storage_options is to be interpreted as headers
#     371 req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 372 with urlopen(req_info) as req:
#     373     content_encoding = req.headers.get("Content-Encoding", None)
#     374     if content_encoding == "gzip":
#     375         # Override compression based on Content-Encoding header
#
# File C:\ProgramData\anaconda3\Lib\site-packages\pandas\io\common.py:274, in urlopen(*args, **kwargs)
#     268 """
#     269 Lazy-import wrapper for stdlib urlopen, as that imports a big chunk of
#     270 the stdlib.
#     271 """
#     272 import urllib.request
# --> 274 return urllib.request.urlopen(*args, **kwargs)
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:216, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     214 else:
#     215     opener = _opener
# --> 216 return opener.open(url, data, timeout)
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:525, in OpenerDirector.open(self, fullurl, data, timeout)
#     523 for processor in self.process_response.get(protocol, []):
#     524     meth = getattr(processor, meth_name)
# --> 525     response = meth(req, response)
#     527 return response
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:634, in HTTPErrorProcessor.http_response(self, request, response)
#     631 # According to RFC 2616, "2xx" code indicates that the client's
#     632 # request was successfully received, understood, and accepted.
#     633 if not (200 <= code < 300):
# --> 634     response = self.parent.error(
#     635         'http', request, response, code, msg, hdrs)
#     637 return response
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:563, in OpenerDirector.error(self, proto, *args)
#     561 if http_err:
#     562     args = (dict, 'default', 'http_error_default') + orig_args
# --> 563     return self._call_chain(*args)
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:496, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     494 for handler in handlers:
#     495     func = getattr(handler, meth_name)
# --> 496     result = func(*args)
#     497     if result is not None:
#     498         return result
#
# File C:\ProgramData\anaconda3\Lib\urllib\request.py:643, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     642 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 643     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404: NOT FOUND

# %% [markdown]
# # Criar Gráficos em MATPLOTLIB e SEABORN

# %% [markdown]
# ## Links Úteis:
#
# **Ajuda Pacakges**
# - MatPLOTLIB: https://matplotlib.org/
# - SEABORN: https://seaborn.pydata.org/
#
#
#
# **Alguns Links com informação o que a ter em conta quando criar gráficos:**
# * [Os 14 principais tipos de gráfico: exemplos e exercícios!](https://blog.betrybe.com/estatistica/principais-tipos-de-grafico![image.png](attachment:image.png))
#     * Apresentação dos principais tipos de gráficos
# * [Unleashing the Power of Data Visualization: Mastering Impactful Insights for Analysts](https://medium.com/@lmota.carla/unleashing-the-power-of-data-visualization-mastering-impactful-insights-for-analysts-75806a94254f)
#     * O que é important na visualização de dados
# - [Remove Your Rose Tinted Glasses: Data Visualizations Designed to Mislead](https://www.datapine.com/blog/misleading-data-visualization-examples/)
#     * Como enganar com gráficos
# - [99 DATA VIZ RULES - & WHY IT’S OK TO BREAK THEM](https://www.addtwodigital.com/blog)
#     - Muitos posts com diferentes regras por exemplo [RULE 18: DON’T USE MULTI-COLOURED BARS](https://medium.com/@addtwo/rule-18-dont-use-multi-coloured-bars-60b265f8a620)
# - [10 Common Data Visualization Mistakes and How to Avoid Them](https://medium.com/agoda-engineering/10-common-data-visualization-mistakes-and-how-to-avoid-them-e3896fe8e104)
#     - Um conjunte de exemplos de erros que podem ser feitos
# * [How to Choose Right Chart for Data: Simple Tips for Effective Visualization](https://bootcamp.uxdesign.cc/mastering-chart-tips-5b45dab736e3)
#     * Como escolher um gráfico
#
#
# **Tutorials**
# - [Matplotlib tutorial for beginners](https://www.kaggle.com/code/prashant111/matplotlib-tutorial-for-beginners)
# - [Seaborn Tutorial for Beginners](https://www.kaggle.com/code/kanncaa1/seaborn-tutorial-for-beginners)
# * [Advanced Matplotlib: A Comprehensive Guide to Data Visualization](https://pub.towardsai.net/advanced-maplotlib-a-comprehensive-guide-to-data-visualization-a2263c863492)
#     * Muitos exemplos
# * [Master Matplotlib: A Step-by-Step Guide for Beginners to Experts](https://medium.com/@hi-sushanta/master-matplotlib-a-step-by-step-guide-for-beginners-to-experts-e76195edff1f)
#     * Apresentação bastante extenso sobre MATPLOTLIB

# %% [markdown]
# ## Importar Dados para os Gráficos
#
# ### Importar tabela da BD
# * BD: BDIFRM (FORMACAO - c21oradev01.int.ine.pt)
# * Tabela com dados por subsecção: TD_BGRI2021_PT
# * Views cm dados C2021
#     - V_BGRI2021_DTMN_PT
#     - V_BGRI2021_DT_PT
#     - V_BGRI2021_N2_PT
#     - V_BGRI2021_N3_PT
# - Atributos a utilizar:
#     - População: N_INDIVIDUOS, N_INDIVIDUOS_65_OU_MAIS
#     - Edifícios: N_EDIFICIOS_CONSTR_ANTES_1945, N_EDIFICIOS_CONSTR_1946_1980
#     - NUTS2
#
# **Dados  População do Recenseamento 2021**
#
# - Queremos saber se existe alguma relação entre:
#     - População com mais de 65 anos
#     - População total por município
# - Outras questões:
#     - Existem outros fatores com influência? Por exemplo a idade dos edifícios que existem no município
#     - Há diferença por área NUTS2

# %%
# Obter Password e Utilizador para Ligacao SQL
from getpass import getpass # para ler a password sem a mostrar
my_user = '"BRUNO.LIMA"' 
my_password = getpass()
# Out:
# ········

# %%
# Ler Dados da BD
# criar conexão
import cx_Oracle 
import pandas as pd
host = 'c21oradev01.int.ine.pt'
port = '1521'
service = 'FORMACAO'
dsn_tns = cx_Oracle.makedsn(host, port, service_name=service) 


# Criar a conexão com todos os elementos,
# incluingo user e password
conn = cx_Oracle.connect(user=my_user, password=my_password, dsn=dsn_tns) 


# Cursor:
# Criar o cursor na conexão conn que criámos antes
c = conn.cursor()

# %%
# Ler Diferentes Views para Pandas DF

# -----------------------------------
# Dados por Municipio:
# SQL String
my_sql = """
select *
from BDIFRM.V_BGRI2021_DTMN_PT 
"""

# Executar o cursor c com a string como parâmetro
c.execute(my_sql)

# Ober Nomes Colunas: (c.description devolva listagem dos atributos, nome atributo é 1º elemento - x[0])
# No Modulo Intermédio devem discutir mais este tipo de metodo para criar Listagem
names = [x[0] for x in c.description]
#print(names)

# Input tabela dentro DataFrame, atribuir nomes colunas
df_mn_c2021 = pd.DataFrame(c.fetchall(), columns = names)

# ---------------------------------
# Dados por NUTS3:

# SQL String
my_sql = """
select *
from BDIFRM.V_BGRI2021_N3_PT 
"""

# Executar o cursor c com a string como parâmetro
c.execute(my_sql)
# Criar Nomes colunas
names = [ x[0] for x in c.description]
df_n3_c2021 = pd.DataFrame(c.fetchall(), columns = names)

# %%
# Solução de recurso caso existem problemas da BD 
import pandas as pd
#df = pd.read_excel(ficheiro) 
df_n3_c2021 = pd.read_excel(r'C:\TEMp\N3_C2021.xlsx')
df_mn_c2021 = pd.read_excel(r'C:\TEMp\DTMN_C2021.xlsx')
# Mostrar informação inicial:
print(df_n3_c2021.head(5))
print(df_mn_c2021.head(5))

# %%
# Criar DF a partir de Ficheiros EXCEL
# "C:\Users\bart.schoen\OneDrive - ineportugal\Documents\2024_FormacaoPython\Dados\DTMN_C2021.xlsx"
# "C:\Users\bart.schoen\OneDrive - ineportugal\Documents\2024_FormacaoPython\Dados\N3_C2021.xlsx"
# Import Packages openxyl para poder trabalhar com XLSX
import pandas as pd
import numpy as np

# Link Direto para ficheiro XLSX
ficheiro_dtmn = r'data\DTMN_C2021.xlsx'
ficheiro_n3 = r'data\N3_C2021.xlsx'
# Importar num DataFrame
df_n3_c2021 = pd.read_excel(ficheiro_n3)
ficheiro_dtmn = pd.read_excel(ficheiro_dtmn) 
# Argumentos uteis: skiprows=[0,1], usecols='A', nrows=2, header=None

# Mostrar primeiras 3 linhas e ultimas 3 linhas (head e tail em conjunto)
# Utilizar iloc e numpy
print(df_n3_c2021.head(5))
print(df_mn_c2021.head(5))
print(df_mn_c2021.info())

# %%
# Mostrar informaçao DF
print(df_n3_c2021.head(5))
print(df_mn_c2021.head(5))
print(df_mn_c2021.info())

# %% [markdown]
# ### Importar dados Mortalidade (DGS)
# * DGS (Certificados de Obitos por Dia):
#     - Descrição dos dados: https://dados.gov.pt/pt/datasets/registos-de-certificados-de-obito/
#     - Link para o ficheiro: https://dados.gov.pt/pt/datasets/r/dde8a843-d6a8-4a3f-82ff-b0e9c6743a3a
#     - Ficheiro a utilizar do drive: evolucao-diaria-de-certificados-de-obito.csv

# %%
# Importar DGS (Certificados de Obitos por Dia)
# Ver referencia: https://dados.gov.pt/pt/datasets/registos-de-certificados-de-obito/
# Atributos: Ano, Mês, Dia do Mês, Dia da Semana, Nº Certificados de Óbito Diários

import pandas as pd

# Link DGS (Certificados de Obitos por Dia)  
ficheiro = r'http://dados.gov.pt/pt/datasets/r/dde8a843-d6a8-4a3f-82ff-b0e9c6743a3a'
# Ler ficheiro do computador:
#ficheiro = r'C:\TEMp\evolucao-diaria-de-certificados-de-obito.csv'

# Importar em DataFrame
df_obitos = pd.read_csv(ficheiro, sep=';')

# Mostrar informação df
print(df_obitos.head(5))
print(df_obitos.info())
print(df_obitos.describe())

# %% [markdown]
# ### Informação DataFrame e Variáveis a utilizar par aos gráficos
# **DataFrames dados C2021**
# - df_n3_c2021: Dados C2021 ao nivel de NUTS3
#      - N_EDIFICIOS_CLASSICOS x N_ALOJAMENTOS_TOTA
#      - N_EDIFICIOS_3_OU_MAIS_PISOS vs N_INDIVIDUOS
# - df_mn_c2021: Dados C2021 - nivel municipio
#
# **DataFrame dados Mortalidade**
# - df_obitos: nº de obitos por dia\mes (DGS)
#     - Utilizar para BAr PLOT
#     - Mostra diferença por ano (Se

# %% [markdown]
# ## Resumo Importação Datasets Utilizados no Notebook

# %% [markdown]
# ### Dados por Municipio e NUTS3

# %%
# Celula REPETIR Importar Dados BD:

# 1. Obter Password e Utilizador para Ligacao SQL
from getpass import getpass # para ler a password sem a mostrar
my_user = '"BRUNO.LIMA"' 
my_password = getpass()


# 2. Ler Dados da BD
# criar conexão
import cx_Oracle 
import pandas as pd
host = 'c21oradev01.int.ine.pt'
port = '1521'
service = 'FORMACAO'
dsn_tns = cx_Oracle.makedsn(host, port, service_name=service) 

# Criar a conexão com todos os elementos,
conn = cx_Oracle.connect(user=my_user, password=my_password, dsn=dsn_tns) 

# Cursor:
c = conn.cursor()

# 3. Ler diferentes Dados para Pandas DF
# df_mn_c2021 e df_n3_c2021
# Dados por Municipio:
# SQL String
my_sql = """
select *
from BDIFRM.V_BGRI2021_DTMN_PT 
"""

# Executar o cursor c com a string como parâmetro
c.execute(my_sql)

# Ober Nomes Colunas: (c.description devolva listagem dos atributos, nome atributo é 1º elemento - x[0])
names = [x[0] for x in c.description]

# Input tabela dentro DataFrame, atribuir nomes colunas
df_mn_c2021 = pd.DataFrame(c.fetchall(), columns = names)

# Dados por NUTS3:

# SQL String
my_sql = """
select *
from BDIFRM.V_BGRI2021_N3_PT 
"""

# Executar o cursor c com a string como parâmetro
c.execute(my_sql)
# Criar Nomes colunas
names = [ x[0] for x in c.description]
df_n3_c2021 = pd.DataFrame(c.fetchall(), columns = names)
# Out:
# ········

# %% [markdown]
# ### Dados Mortalidade DGS

# %%
# Importar DGS (Certificados de Obitos por Dia)
# Ver referencia: https://dados.gov.pt/pt/datasets/registos-de-certificados-de-obito/
# Atributos: Ano, Mês, Dia do Mês, Dia da Semana, Nº Certificados de Óbito Diários

import pandas as pd

# Link DGS (Certificados de Obitos por Dia)  
ficheiro = r'http://dados.gov.pt/pt/datasets/r/dde8a843-d6a8-4a3f-82ff-b0e9c6743a3a'
# Ler ficheiro do computador:
#ficheiro = r'C:\TEMp\evolucao-diaria-de-certificados-de-obito.csv'

# Importar em DataFrame
df_obitos = pd.read_csv(ficheiro, sep=';')

# Mostrar informação df
print(df_obitos.head(5))
print(df_obitos.info())
print(df_obitos.describe())
# Out:
#       Período   Ano  Mês  Dia do Mês Dia da Semana  \
# 0  2014-01-02  2014    1           2  quinta-feira
# 1  2014-01-03  2014    1           3   sexta-feira
# 2  2014-01-15  2014    1          15  quarta-feira
# 3  2014-01-17  2014    1          17   sexta-feira
# 4  2014-01-18  2014    1          18        sábado
#
#    Nº Certificados de Óbito Diários
# 0                               344
# 1                               375
# 2                               345
# 3                               331
# 4                               297
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3743 entries, 0 to 3742
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Período                           3743 non-null   object
#  1   Ano                               3743 non-null   int64
#  2   Mês                               3743 non-null   int64
#  3   Dia do Mês                        3743 non-null   int64
#  4   Dia da Semana                     3743 non-null   object
#  5   Nº Certificados de Óbito Diários  3743 non-null   int64
# dtypes: int64(4), object(2)
# memory usage: 175.6+ KB
# None
#                Ano          Mês   Dia do Mês  Nº Certificados de Óbito Diários
# count  3743.000000  3743.000000  3743.000000                       3743.000000
# mean   2018.633449     6.413572    15.726690                        317.341972
# std       2.960956     3.479719     8.799953                         69.535079
# min    2014.000000     1.000000     1.000000                         22.000000
# 25%    2016.000000     3.000000     8.000000                        270.000000
# 50%    2019.000000     6.000000    16.000000                        308.000000
# 75%    2021.000000     9.000000    23.000000                        350.000000
# max    2024.000000    12.000000    31.000000                        792.000000

# %% [markdown]
# ## Listagem Gráficos para Criar
#
# -  Gráfico de dispersão (Scatter Plots)
#     - MatPlotLIB
#     - SeaBorn
# - Gráfico de contagens (Countplot)
# - Gráfico de Barras (Bar Plots)
# - Box Plots
# - Gráfico de linhas (Line Plots)
# - Histograma (Histogram)

# %% [markdown]
# ## Gráfico de Dispersão (Scatterplot)
#
# - Existem 2 variáveis contínuas
#     - Podem ser incluídas categorias
#     - Valores de uma 3ª variável contínua
# - Utilizar para obter informação sobre a relação entre estas 2 variáveis
#
# - Exemplo

# %% [markdown]
# ### Gráfico de Dispersão (Scatterplot)  em MATPLOTLIB
# - [Ajuda Scatterplot MATPLOTLIB](https://matplotlib.org/stable/gallery/shapes_and_collections/scatter.html)

# %%
# Importar pyplot do matplotlib 
from matplotlib import pyplot as plt

# %% [markdown]
# #### Gráfico Relação Grupos Etários com Tamanho Municipio

# %%
# Import matplotlib
from matplotlib import pyplot as plt

# Scatterplot que conssite de 2 plots
# 1º plot: Mostrar nº de indivíduos no áxis X, Y áxis: nº de indivíduos com idade superior a 65 
# 2º plot: Mostrar nº de indivíduos no áxis X, Y áxis: nº de indivíduos com idade inferior a 14  


# Marker: circle ('o'), point ('.'), diamond('d'), or square ('s')
# s - tamamnho
# label - rótulo a colocar
# alpha - transparência
# Plot 1
plt.scatter(df_mn_c2021.N_INDIVIDUOS, df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS,
                color = 'Red', 
                marker='.', 
                s=12,
                label = '65 ou mais', 
                alpha = 0.5)
# Plot 2
plt.scatter(df_mn_c2021.N_INDIVIDUOS, df_mn_c2021.N_INDIVIDUOS_0_14,
                color = 'Green', 
                marker='s', 
                s=12,
                label = '15 ou menos', 
                alpha = 0.5) 
# Definir Labels x e y áxis
plt.xlabel('Nº Individuos')
plt.ylabel('Nº Individuos por grupo')

# Adicionar GRID
plt.grid(True)

# Definir Título
plt.title('Relação Individuos por grupo idade ao total \n por municipio',size=12,fontweight="bold")

# Mostrar Legenda
plt.legend()
plt.show()

# %% [markdown]
# #### Gráfico Relação Grupos Etários com Tamanho Municipio (valores relativos)

# %%
from matplotlib import pyplot as plt

# É possivel dividir as variáveis!
# Permita tirar conclusões dos dados
plt.scatter(df_mn_c2021.N_INDIVIDUOS/1000, df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS,
               color = 'Red', s=12, marker='.', label = '65 ou mais', alpha = 0.5)
# 2º plot com 
plt.scatter(df_mn_c2021.N_INDIVIDUOS/1000, df_mn_c2021.N_INDIVIDUOS_0_14/df_mn_c2021.N_INDIVIDUOS,
               color = 'Green', s=12, marker='s', label = '15 ou menos', alpha = 0.5) # 
#'''
# Labels x e y áxis
plt.xlabel('Nº Individuos (por 1000)')
plt.ylabel('Rácio nº Individuos')
# Adicionar GRID
plt.grid(True)
plt.title('Relação Individuos por grupo idade ao total \n por municipio',size=12,fontweight="bold")
# Mostrar Legenda
plt.legend()
plt.style.use('fivethirtyeight')
#plt.title
plt.show()

# %% [markdown]
# #### Criar a mesma Figura utilizando os objectos _fig_ e _ax_
#
# **Diferençãs no código**
# ~~~Python
# # Codigo criar Plot ax.scatter() em vez de plt.scatter()
# from matplotlib import pyplot as plt
# fig,ax = plt.subplots()
# ax.scatter(df_mn_c2021.N_INDIVIDUOS, df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS,
#                 color = 'Red',
#                 marker='.',
#                 s=12,
#                 label = '65 ou mais',
#                 alpha = 0.5)
#
# # Definir Elementos, neste caso Label, Title
# ax.set_xlabel('Nº Individuos')
# ax.set_ylabel('Nº Individuos por grupo')
#
# # Definir Título
# ax.set_title('Relação Individuos por grupo idade ao total \n por municipio',size=12,fontweight="bold")
# ~~~~
#
# **Atenção:**
# - Neste metodo estamos a criar os plots diretamente com MATPLOTLIB e não com o módulo PYPLOT (plt)
# - Diferença no sintaxe: por exemplo ax.set_xlabel vs plt.xlabel
# - Criar fig,ax important para criar subplots

# %%
# Import matplotlib
from matplotlib import pyplot as plt
fig,ax = plt.subplots()

# Scatterplot que conssite de 2 plots
# 1º plot: Mostrar nº de indivíduos no áxis X, Y áxis: nº de indivíduos com idade superior a 65 
# 2º plot: Mostrar nº de indivíduos no áxis X, Y áxis: nº de indivíduos com idade inferior a 14  

ax.scatter(df_mn_c2021.N_INDIVIDUOS/1000, df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS,
            color = 'Red', 
           s=12, 
           marker='.', 
           label = '65 ou mais', 
           alpha = 0.5)
# 2º plot com 
ax.scatter(df_mn_c2021.N_INDIVIDUOS/1000, df_mn_c2021.N_INDIVIDUOS_0_14/df_mn_c2021.N_INDIVIDUOS,
               color = 'Green', 
               s=12, 
               marker='s', 
               label = '15 ou menos', 
               alpha = 0.5) # 



# Definir Labels x e y áxis
ax.set_xlabel('Nº Individuos')
ax.set_ylabel('Nº Individuos por grupo')

# Adicionar GRID
ax.grid(True)

# Definir Título
ax.set_title('Relação Individuos por grupo idade ao total \n por municipio',size=12,fontweight="bold")


# Mostrar Legenda
plt.legend()
plt.show()

# %% [markdown]
# ###  ScatterPlot em SEABORN
# - [Ajuda Scatterplot SEABORN](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %% [markdown]
# #### Seaborn Scatterplot Inicial

# %%
# Grafico Scatterplot SEABORN - Inicial
import seaborn as sns
from matplotlib import pyplot as plt

# Criar Gráfico
sns.scatterplot(x=df_mn_c2021.N_INDIVIDUOS, 
                y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS, 
                data = df_mn_c2021
               )
plt.show()

# %% [markdown]
# ####  Seaborn adicionar  cor como 3º elemento
# - [Seaborn color palettes](https://seaborn.pydata.org/tutorial/color_palettes.html)

# %%
# Grafico Scatterplot SEABORN - Incluir cor
import seaborn as sns
from matplotlib import pyplot as plt

# Importar palete de cores
sns.set_palette('Accent')

# Criar Gráfico
# hue - atributo para cor
# hue_order - order cores na legenda
sns.scatterplot(x=df_mn_c2021.N_INDIVIDUOS/1000, 
                y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS, 
                data = df_mn_c2021,
                hue = "NUTS2",
                hue_order = ['11','15','16','17','18','20','30']
               )
plt.show()

# Alternativa Order List
hue_order_list = sorted(df_mn_c2021['NUTS2'].unique())

# %% [markdown]
# #### Seaborn adicionar tamanho

# %%
# Grafico Scatterplot SEABORN - Incluir cor
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_palette('Accent')

# Criar Gráfico
# size - variavel para tamanho de cada ponto
sns.scatterplot(x=df_mn_c2021.N_INDIVIDUOS/1000, 
                y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS, 
                data = df_mn_c2021,
                hue = "NUTS2",
                hue_order = ['11','15','16','17','18','20','30'],
                # Relação entre edificios até 1980 no total de edificios
                size = (df_mn_c2021.N_EDIFICIOS_CONSTR_ANTES_1945 + 
                        df_mn_c2021.N_EDIFICIOS_CONSTR_1946_1980) /
                    df_mn_c2021.N_EDIFICIOS_CLASSICOS
               )
plt.show()

# %% [markdown]
# ## SEABORN RELPLOT

# %% [markdown]
# ### SEABORN REPLOT Inicial

# %%
# Grafico Scatterplot SEABORN - Incluir cor
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_palette('Accent')

# Criar Gráfico
sns.relplot(x=df_mn_c2021.N_INDIVIDUOS/1000, 
                y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS, 
                data = df_mn_c2021,
                kind = "scatter",
                col = "NUTS2",
                col_order = ['11','15','16','17','18','20','30'],
                # Numero colunas
                col_wrap = 3,
                size = (df_mn_c2021.N_EDIFICIOS_CONSTR_ANTES_1945 + 
                        df_mn_c2021.N_EDIFICIOS_CONSTR_1946_1980) /
                    df_mn_c2021.N_EDIFICIOS_CLASSICOS,
                # Tamanho minimo e máximo
                sizes=(10, 150),
                alpha = 0.7
               )
plt.show()

# %%
# Outro Exemplo com Municipios com menos de 50000 e mais que 50000
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
sns.set_style('whitegrid')

# Criar Nova Coluna para indicar tamanho do municipio (2 classes)
df_mn_c2021["Tipo Municipio"] = np.where(df_mn_c2021.N_INDIVIDUOS<50000, 'Menos 50.000', 'Mais 50.000')

# Mostra população com mais de 65 anos por tipo de municipio
sns.relplot(x=df_mn_c2021.N_INDIVIDUOS/1000, 
                y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS,
                data = df_mn_c2021,
           kind="scatter",
           col=df_mn_c2021["Tipo Municipio"]           
           )
plt.show()

# %% [markdown]
# ### Mesmo Figura Utilizando MATPLOTLIB
#
# - Criar com subplots
# - Envolve escrever mais código, loop ou criar funções
# - O número de categorias não pode corresponder com o total de subplots (nº de linhas x nº de colunas)

# %%
import matplotlib.pyplot as plt
import pandas as pd

# Criar os SubPlots - Deifnir nº linhas e colunas
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))

# Criar Subplot para Cada NUTS2
# NUTS2: 11
df_nut2 = df_mn_c2021[df_mn_c2021['NUTS2'] == '11']

# Definir onde colocar o plot
# É possivel incluir 'x=...' e 'y=...' no codigo 
ax_11 = axes[0, 0]
ax_11.scatter(
    x=df_nut2['N_INDIVIDUOS'] / 1000,
    y=df_nut2['N_INDIVIDUOS_65_OU_MAIS'] / df_nut2['N_INDIVIDUOS'],
    s=(df_nut2['N_EDIFICIOS_CONSTR_ANTES_1945'] +
       df_nut2['N_EDIFICIOS_CONSTR_1946_1980']) / df_nut2['N_EDIFICIOS_CLASSICOS'] * 1000,  
    alpha=0.7,
    label='11'
)
ax_11.set_xlabel('N_INDIVIDUOS (thousands)')
ax_11.set_ylabel('N_INDIVIDUOS_65_OU_MAIS / N_INDIVIDUOS')
ax_11.set_title('NUTS2: 11')
ax_11.legend()

# NUTS2: 15
df_nut2 = df_mn_c2021[df_mn_c2021['NUTS2'] == '15']
ax_15 = axes[0, 1]
ax_15.scatter(
    x=df_nut2['N_INDIVIDUOS'] / 1000,
    y=df_nut2['N_INDIVIDUOS_65_OU_MAIS'] / df_nut2['N_INDIVIDUOS'],
    s=(df_nut2['N_EDIFICIOS_CONSTR_ANTES_1945'] +
       df_nut2['N_EDIFICIOS_CONSTR_1946_1980']) / df_nut2['N_EDIFICIOS_CLASSICOS'] * 1000,  
    alpha=0.7,
    label='15'
)
ax_15.set_xlabel('N_INDIVIDUOS (thousands)')
ax_15.set_ylabel('N_INDIVIDUOS_65_OU_MAIS / N_INDIVIDUOS')
ax_15.set_title('NUTS2: 15')
ax_15.legend()

# Repetir para os outros NUTS2

plt.tight_layout()
plt.show()

# %% [markdown]
# **Alternativa utilizar um loop**

# %%
# 
# Import matplotlib
from matplotlib import pyplot as plt

# Create subplots
fig, axes = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))

# Mudar o array de 2 dimensõe spara listagem, facilitando a definição do subplot
axes = axes.flatten()  

# Define NUTS2 order
nut2_order = ['11', '15', '16', '17', '18', '20', '30']


# Percorrer cada NUTS2 e criar um SUBPLOT
for i, nut2 in enumerate(nut2_order[:7]):
    
    # Definir ax para subplot (0...n)
    ax = axes[i]
    # Seleção dos dados NUTS2
    df_nut2 = df_mn_c2021[df_mn_c2021['NUTS2'] == nut2]
    # Criar SUBPLOT
    ax.scatter(
        df_nut2['N_INDIVIDUOS'] / 1000,
        df_nut2['N_INDIVIDUOS_65_OU_MAIS'] / df_nut2['N_INDIVIDUOS'],
        s=(df_nut2['N_EDIFICIOS_CONSTR_ANTES_1945'] +
           df_nut2['N_EDIFICIOS_CONSTR_1946_1980']) / df_nut2['N_EDIFICIOS_CLASSICOS'] * 1000,  
        alpha=0.7,
        label=nut2
    )
    ax.set_xlabel('N_INDIVIDUOS (thousands)')
    ax.set_ylabel('N_INDIVIDUOS_65_OU_MAIS / N_INDIVIDUOS')
    ax.set_title(f'NUTS2: {nut2}')
    ax.legend()

plt.tight_layout(pad=1.5)
plt.show()

# %% [markdown]
# ## SeaBorn CATPLOTs
# - [Ajuda CATPLOT](https://seaborn.pydata.org/generated/seaborn.catplot.html)

# %% [markdown]
# ### Gráfico de contagens (CountPlot)
# - [Ajuda COUNTPLOT](https://seaborn.pydata.org/generated/seaborn.countplot.html)

# %%
# Criar COUNTPLOT - Contagens de registos por ano
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_palette('Accent')

# Ordenar no Notebook de demonstração
category_order = sorted(df_obitos['Ano'].unique(),reverse=True)

# Criar Gráfico
sns.catplot(x="Ano", # x ou y
            data = df_obitos,
            kind = "count",
            order = category_order
            
               )
plt.show()

# %% [markdown]
# ### Gráfico de barras (Bar plot)
#
# - [Ajuda Barplot](https://seaborn.pydata.org/generated/seaborn.barplot.html)
# - [Informação sobre error bars](https://seaborn.pydata.org/tutorial/error_bars.html)

# %%
# Criar Barplot - Contagens de nº de óbitos diarios por ano
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_palette('Accent')

# Gráfico com nº de óbitos diários por ano
sns.catplot(x="Ano",
            y = 'Nº Certificados de Óbito Diários',
            data = df_obitos,
            kind = "bar",
            # Error bar mostra Interval de confiança (ci) 
            errorbar = 'ci' # None\'ci\sd\se\pi\metodo definido'
            )
plt.show()

# %% [markdown]
# ### Box plot
#
# - [Ajuda Boxplot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)

# %%
# Criar BOXPLOT - Distribuição dos ceritficados Óbito Diários
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_palette('tab10')
# Mudar o aspecto do output
#sns.set_context('notebook')

# Gráfico mostra a distribuição de nº de óbitos diários
sns.catplot(x="Dia da Semana", # Dia da Semana
            y = 'Nº Certificados de Óbito Diários',
            data = df_obitos,
            kind = "box",
            whis = [5,95] # 2.0
            # sym = '' # - controlar visualização outliers
            )
plt.show()

# %% [markdown]
# ## Criar plots com ou sem RELPLOT\CATPLOT

# %% [markdown]
# ### Gráfico de linhas (LINEPLOT)
#
# - [Ajuda Lineplot](https://seaborn.pydata.org/generated/seaborn.lineplot.html)

# %%
# Mostrar Percentagem pop65 no total
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_palette('Accent')

# Nova Coluna com Ano e Mes
# Criar Nova Coluna para indicar tamanho do municipio
# Converter para String e Juntar
df_obitos["ANO_MES"] = df_obitos['Ano'].astype(str) + df_obitos['Mês'].astype(str)

# Criar Gráfico nº de óbitos por ano e mes
g1 = sns.relplot(x='ANO_MES',
             y= 'Nº Certificados de Óbito Diários', 
            data = df_obitos,
            kind = 'line',
             color = 'green',
             errorbar = 'ci' # Mudar de ci para sd
               )

plt.show()

# Grafico com Lineplot com seleção dos anos 2015 até 2016

df_obitos2015_2016 = df_obitos[df_obitos['Ano'].isin([2015, 2016, 2017])]
g2 = sns.lineplot(x='ANO_MES',
             y= 'Nº Certificados de Óbito Diários', 
            data = df_obitos2015_2016,
             color = 'red',
             errorbar = 'sd' # Mudar de ci para sd
               )

# Get the x-axis tick positions and labels
xtick_positions = g2.get_xticks()
xtick_labels = df_obitos2015_2016['ANO_MES'].iloc[xtick_positions].tolist()

# Set x-axis tick labels to show only every 12th label
filtered_xtick_labels = [label if i % 12 == 0 else '' for i, label in enumerate(xtick_labels)]
g2.set_xticks(xtick_positions)
g2.set_xticklabels(filtered_xtick_labels, rotation=45)  # You can adjust rotation as needed



        
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
g1
plt.show()

# %% [markdown]
# ### Histograma (Histogram)
#
# - [Ajuda Seaborn](https://seaborn.pydata.org/generated/seaborn.histplot.html)

# %%
# histograma que mostra a distribuição do rácio de população com mais de 65 anos
import seaborn as sns
from matplotlib import pyplot as plt

sns.set_palette('Accent')

# Alternativa Order List
hue_order_list = sorted(df_mn_c2021['NUTS2'].unique())

# Criar Gráfico com sns.histplot
sns.histplot(x=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS, 
            data = df_mn_c2021,
             bins = 30,
             #binwidth = 0.02, - Alternativa definir tamanho de cada bin
            hue = "NUTS2",
            hue_order = ['11','15','16','17','18','20','30']
               )
plt.show()
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Customização dos gráficos em SEABORN
# - [Customizing Seaborn plots: ](https://goodboychan.github.io/python/datacamp/visualization/2020/06/27/01-Customizing-Seaborn-Plots.html)
# - [Palette list:](https://www.practicalpythonfordatascience.com/ap_seaborn_palette)
# - [Palettes Seaborn:](https://seaborn.pydata.org/tutorial/color_palettes.html)
# - [Styles disponíveis: ](https://seaborn.pydata.org/tutorial/aesthetics.html)

# %% [markdown]
# ### Visualizar Global
# - [set_style](https://seaborn.pydata.org/generated/seaborn.set_style.html)
# - [set_palette](https://seaborn.pydata.org/generated/seaborn.set_palette.html)
# - [Choosing color palettes](https://seaborn.pydata.org/tutorial/color_palettes.html)
# - [set_context](https://seaborn.pydata.org/generated/seaborn.set_context.html)

# %%
# Exemplo diferenças na visualização com estes 3 paramentros
import seaborn as sns
from matplotlib import pyplot as plt

# Categorical Color Brewer palettes: 'tab10' (default matplotlib palette), 'Dark2', 'Pastel1', 'Set2', 'Paired'
# Seaborn has six variations of matplotlib’s palette, called: deep, muted, pastel, bright, dark, and colorblind
sns.set_palette('colorblind')
# 'paper',  'notebook', 'talk', 'poster'
sns.set_context('paper')
# Atenção - estilo continua valido para o resto do codigo
# darkgrid, whitegrid, dark, white, ticks
sns.set_style('darkgrid')
# Mudar o aspecto do output


# Gráfico mostra a distribuição de nº de óbitos diários
sns.catplot(x="Dia da Semana", # Dia da Semana
            y = 'Nº Certificados de Óbito Diários',
            data = df_obitos,
            kind = "box",
            whis = [5,95]# 2.0
            #sym = '' # - controlar mostrar outliers
            )
plt.show()

# %%
# Demonstração diferentes STYLES

import seaborn as sns
from matplotlib import pyplot as plt

# darkgrid, whitegrid, dark, white, ticks
for estilo in ['darkgrid', 'whitegrid', 'dark', 'white', 'ticks']:
    sns.set_style(estilo)
    sns.set_palette('Accent')

    # Criar Gráfico
    sns.relplot(x=df_mn_c2021.N_INDIVIDUOS/1000, 
                    y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS, 
                    data = df_mn_c2021,
                    kind = "scatter",
                    hue = 'NUTS2')
    print(estilo.upper())
    plt.show()



plt.show()

# %% [markdown]
# ### 2 tipos de plots em Seaborn
# **Existe uma diferença no objecto do devolvido**

# %%
# Diferentes tipos de plots em Seaborn
# 
g1 = sns.scatterplot(x=df_mn_c2021.N_INDIVIDUOS,y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS, data = df_mn_c2021)
g2 = sns.relplot(x=df_mn_c2021.N_INDIVIDUOS,y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS, data = df_mn_c2021,kind='scatter')
print(type(g1))
print(type(g2))

# %% [markdown]
# ### Adicionar Titulos
# - [Controlar seaborn titles](https://datagy.io/seaborn-titles/)
# - [Suptitle() é função do matplotlib](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.suptitle.html)

# %%
# Definições globais:
sns.set_style('ticks')
sns.set_palette('colorblind')
sns.set_context('notebook')

# # Criar Gráfico
g = sns.relplot(x=df_mn_c2021.N_INDIVIDUOS/1000, 
                y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS, 
                data = df_mn_c2021,
                kind = "scatter",
                hue = 'NUTS2',
               col='NUTS1')

# Definir Titulo e font do titulo
g.fig.suptitle('Relacao população 65+ no total de população',
               y = 1.05,
              fontdict={'size': 20, 'color': 'black','name': 'Arial'})

g.set_titles("NUTS1 {col_name}")

plt.show()

# %% [markdown]
# ### Mudar Rotulos dos Eixos

# %%
g = sns.relplot(x=df_mn_c2021.N_INDIVIDUOS/1000, 
                y=df_mn_c2021.N_INDIVIDUOS_65_OU_MAIS/df_mn_c2021.N_INDIVIDUOS, 
                data = df_mn_c2021,
                kind = "scatter",
                hue = 'NUTS2',
               col='NUTS1')

g.fig.suptitle('Relacao população 65+ no total de população',
               y = 1.05,
              fontdict={'color': 'black','name': 'Arial'})

g.set_titles("NUTS1 {col_name}")

# Rotulos Eixos
# .set - permite definir atributos para cada eixo de um FacetGrid
g.set(xlabel="População por municipio (em 1000)",
     ylabel="Rácio nº Individuos superior a 65 anos")

plt.show()

'''
# Gravar Ficheiro:
outputfile = r'c:\temp\omeuplot.png'
g.savefig(outputfile, format='png')

'''

# %% [markdown]
# ### Gravar Plot para Imagem
# - [matplotlib.pyplot.savefig](https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.savefig.html)
#
# ~~~Python
# outputfile = r'c:\temp\omeuplot.png'
# g.savefig(outputfile, format='png')
# ~~~

# %% [markdown]
# # Exercicios

# %% [markdown]
# ## Dados a Utilizar
# ** Dataset do DGS com análise dos utentos nos CS**
# *  [Descrição dos dados] (https://dados.gov.pt/pt/datasets/evolucao-mensal-de-utentes-atendidos-nos-centros-de-saude-agregado-por-aces-no-ambito-da-saude-oral-nos-cuidados-de-saude-primarios-socsp/#resources)
# * Link dados: http://dados.gov.pt/pt/datasets/r/dc54ea6f-31f3-483b-a719-718d0d7451f3

# %% [markdown]
# ## Exercício 1
# **Importar e ver Características dos dados**
# - Importa os dados diretamente pelo link (ou do drive)
# - Obtem os nomes das variáveis
# - Visualiza informação do ficheiro
#
#
# **Dicas**:
# ~~~Python
# pd.read_csv
# df.head
# df.info
# df.describe
# ~~~~

# %% [markdown]
# ## Exercício 2
# **Mostrar num BOXPLOT a distribuíção por ARS dos diferentes nº de utentes por Sexo**
# - Variáveis: ARS, Sexo, Nº Utentes
# - Podem mudar o aspecto do gráfico com os parâmetros  globais de visualização
# - Controlam a visualização das hastes\"whiskers" e valores atípicos\"outliers"
# - [Boxplot em Seaborn](https://seaborn.pydata.org/generated/seaborn.boxplot.html#seaborn.boxplot)
#
#
# **Dicas**:
# ~~~Python
# sns.set_palette(),sns.set_context(), sns.set_style()
# sns.boxplot(x,y,hue,data)
# whis =
# sym =
# ~~~~

# %% [markdown]
# ## Exercício 3
# **Mostrar num LINEPLOT o nº de utentos por Ano por ARS**
# - Variáveis: Período, ARS, Nº Utentes
# - Para implementar devem:
#     - Criar novo variável Ano no dataframe (ver código)
#     - Criar um Relplot do tipo 'line'
#
#
#
# **Dicas**:
# ~~~Python
# # Criar novo variável ano no Dataframe:
# # Converter "Período" para formato datetime
# df['Período'] = pd.to_datetime(df_utentes['Período'], format='%Y-%m')
#
# # Extrair o ano e criar nova coluna ANO
# df['ANO'] = df_utentes['Período'].dt.year
#
# # Partes do codigo para Lineplot
# sns.relplot(kind = ,color = , col = df[''], col_order = , col_wrap = , errorbar =
#
# ~~~~

# %% [markdown]
# ## Desafio utilizar o package CUTECHARTS
#
# - A biblioteca Cutecharts faz gráficos tipo desenhado a mão (exemplo de muitas bibliotecas de visualização que existem)
#
#
# **Desafio**
# - Utiliza a informação da página https://www.kaggle.com/code/anandhuh/introduction-to-cutecharts-library com código para criar um piechart
# - A partir do dataset com informação do Censos 2021 (df_n3_c2021 ou df_mn_c2021) cria a seguinte figura que mostra a população por NUTS2
# ![image.png](attachment:image.png)
#
# - Algumas dicas:
#     - Seria necessário de instalar o cutecharts com 'pip install cutecharts' no prompt anaconda
#     - Deve-se fazer um groupby da coluna NUTS2 com somatório do total de populaçao (N_INDIVIDUOS)
