# %% [markdown]
# # O meu diário de  Data Science
# ## Notas e Experiências
# ![eae5afd1-eb2c-443c-8ea6-f271aad5dd60.jpeg](data:image/jpeg;base64,...)

# %%
# Escrever uma célula de código Python com:
# 1. uma variável chamada multiplicador, com o valor aleatório inteiro entre 2 e 8 (inclusivo)
from random import randint
multiplicador = randint(2, 9)

# 2. Pedir ao utilizador que insira um número (e guardar o valor numa variável)
numero = int(input("insira um número:\n"))

# 3. Imprimir no ecrã o valor do multiplicador e o resultado de multiplicar o multiplicador pelo valor inserido pelo utilizador
print("multiplicador:",multiplicador)
print(f"{multiplicador} x {numero} = {multiplicador * numero}")
